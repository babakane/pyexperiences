# %% [markdown]
# # Analyze, manipulate, and visualize time series data

# %% [markdown]
#                                                                 A practice from towardsdatascience

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
from pandas_datareader import data
apple = data.DataReader("AAPL", start='2019-1-1', end='2020-12-1',
                        data_source='yahoo')
google = data.DataReader("GOOG", start='2019-1-1', end='2020-12-1',
                        data_source='yahoo')

# %%
apple
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-01-02   39.712502   38.557499   38.722500   39.480000  148158800.0
# 2019-01-03   36.430000   35.500000   35.994999   35.547501  365248800.0
# 2019-01-04   37.137501   35.950001   36.132500   37.064999  234428400.0
# 2019-01-07   37.207500   36.474998   37.174999   36.982498  219111200.0
# 2019-01-08   37.955002   37.130001   37.389999   37.687500  164101200.0
# ...                ...         ...         ...         ...          ...
# 2020-11-24  115.849998  112.589996  113.910004  115.169998  113874200.0
# 2020-11-25  116.750000  115.169998  115.550003  116.029999   76499200.0
# 2020-11-27  117.489998  116.220001  116.570000  116.589996   46691300.0
# 2020-11-30  120.970001  116.809998  116.970001  119.050003  169410200.0
# 2020-12-01  123.470001  120.010002  121.010002  122.720001  128166800.0
#
#              Adj Close
# Date
# 2019-01-02   38.562561
# 2019-01-03   34.721451
# 2019-01-04   36.203678
# 2019-01-07   36.123104
# 2019-01-08   36.811718
# ...                ...
# 2020-11-24  115.169998
# 2020-11-25  116.029999
# 2020-11-27  116.589996
# 2020-11-30  119.050003
# 2020-12-01  122.720001
#
# [484 rows x 6 columns]

# %%
google
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-01-02  1052.319946  1015.710022  1016.570007  1045.849976  1532600
# 2019-01-03  1056.979980  1014.070007  1041.000000  1016.059998  1841100
# 2019-01-04  1070.839966  1027.417969  1032.589966  1070.709961  2093900
# 2019-01-07  1074.000000  1054.760010  1071.500000  1068.390015  1981900
# 2019-01-08  1084.560059  1060.530029  1076.109985  1076.280029  1764900
# ...                 ...          ...          ...          ...      ...
# 2020-11-24  1771.599976  1727.689941  1730.500000  1768.880005  1578000
# 2020-11-25  1778.540039  1756.540039  1772.890015  1771.430054  1045800
# 2020-11-27  1804.000000  1772.439941  1773.089966  1793.189941   884900
# 2020-11-30  1788.064941  1755.000000  1781.183960  1760.739990  1823800
# 2020-12-01  1824.829956  1769.369995  1774.369995  1798.099976  1739000
#
#               Adj Close
# Date
# 2019-01-02  1045.849976
# 2019-01-03  1016.059998
# 2019-01-04  1070.709961
# 2019-01-07  1068.390015
# 2019-01-08  1076.280029
# ...                 ...
# 2020-11-24  1768.880005
# 2020-11-25  1771.430054
# 2020-11-27  1793.189941
# 2020-11-30  1760.739990
# 2020-12-01  1798.099976
#
# [484 rows x 6 columns]

# %%
apple.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
google.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
plt.figure(figsize=(12,6))
apple['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(nrows=2, sharex=True, figsize=(12,6))
apple['Close'].plot(ax=ax[0], title="Apple Stock", legend=False)
google['Close'].plot(ax=ax[1], title="Google Stock", legend=False)
# Out:
# <AxesSubplot:title={'center':'Google Stock'}, xlabel='Date'>

# %% [markdown]
# ## Comparasion of both apple and google upon daily volum sales

# %%
# change name to volume
fig, ax = plt.subplots(nrows=2, sharex=True, figsize=(12,6))
apple['Volume'].plot(ax=ax[0], title="Apple Stock - Volume", legend=False)
google['Volume'].plot(ax=ax[1], title="Google Stock - Volume", legend=False)
# Out:
# <AxesSubplot:title={'center':'Google Stock - Volume'}, xlabel='Date'>

# %% [markdown]
# ## Resampling: Representing data with different frequency

# %%
fig, ax = plt.subplots(nrows=2, sharex=True, figsize=(12,6))
apple['Volume'].resample('7D').mean()\
.plot(ax=ax[0], title="Apple Stock - Volume", legend=False)
google['Volume'].resample('7D').mean()\
.plot(ax=ax[1], title="Google Stock - Volume", legend=False)
# Out:
# <AxesSubplot:title={'center':'Google Stock - Volume'}, xlabel='Date'>

# %% [markdown]
# ## Roling

# %%
fig, ax = plt.subplots(nrows=2, sharex=True, figsize=(12,6))
apple['Volume'].rolling(7).mean()\
.plot(ax=ax[0], title="Apple Stock - Volume", legend=False)
google['Volume'].rolling(7).mean()\
.plot(ax=ax[1], title="Google Stock - Volume", legend=False)
# Out:
# <AxesSubplot:title={'center':'Google Stock - Volume'}, xlabel='Date'>
